# %%
import os, sys
import numpy as np
import pyvista as pv
import matplotlib.pyplot as plt
from scipy.constants import c 

sys.path.append('../../')

from solverFIT3D import SolverFIT3D
from gridFIT3D import GridFIT3D 
from wakeSolver import WakeSolver



wake = WakeSolver()
wake.load_results('results_beta09_sigma100_wl40')

# %% [markdown]
# ## Plot

# %%
# CST_wake = np.loadtxt('/home/emacchia/wakis/benchmarks/betacavity/results_beta1_sigma1e3/CST_wake_z_beta1.txt')
# CST wake and impedance
# cstWP = wake.read_txt('results_beta07_sigma100_wl21/CSTwake.txt')
CST_wake = np.loadtxt('./results_beta09_sigma100_wl40/CSTwake.txt')
cst_s = CST_wake[:,0]
cst_WP = CST_wake[:,1]
cstZ = wake.read_txt('results_beta09_sigma100_wl40/CSTZ.txt')
cstZReIm = wake.read_txt('results_beta09_sigma100_wl40/CSTZReIm.txt')


fig, ax = plt.subplots(1,2, figsize=[12,4], dpi=150)
ax[0].plot(wake.s*1e2, wake.WP, c='r', lw=1.5, label='FIT+Wakis')
ax[0].plot(cst_s[cst_s<2500], cst_WP[cst_s<2500], c='k', ls='--', lw=1.5, label='CST')
ax[0].set_xlabel('s [cm]')
ax[0].set_ylabel('Longitudinal wake potential [V/pC]', color='r')
ax[0].legend()

ax[1].plot(wake.f*1e-9, np.abs(wake.Z), c='b', lw=1.5, label='FIT+Wakis')
ax[1].plot(cstZ[0], cstZ[1], c='k', ls='--', lw=1.5, label='CST')
ax[1].set_xlabel('f [GHz]')
ax[1].set_ylabel('Longitudinal impedance [Abs][$\Omega$]', color='b')
ax[1].legend()

#fig.suptitle('Benchmark with CST Wakefield Solver')
fig.tight_layout()
fig.savefig('results_beta09_sigma100_wl40/cfr_wake_Zmag.png')

plt.show()
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\O'
# <>:21: SyntaxWarning: invalid escape sequence '\O'
# /tmp/ipykernel_1379871/2599827597.py:21: SyntaxWarning: invalid escape sequence '\O'
#   ax[1].set_ylabel('Longitudinal impedance [Abs][$\Omega$]', color='b')

# %%
# CST_wake = np.loadtxt('/home/emacchia/wakis/benchmarks/betacavity/results_beta1_sigma1e3/CST_wake_z_beta1.txt')
# CST wake and impedance



fig, ax = plt.subplots(1,2, figsize=[12,4], dpi=150)
ax[0].plot(wake.f*1e-9, np.real(wake.Z), c='r', lw=1.5, label='FIT+Wakis')
ax[0].plot(cstZReIm[0], cstZReIm[1], c='k', ls='--', lw=1.5, label='CST')
ax[0].set_xlabel('f [GHz]')
ax[0].set_ylabel('Longitudinal impedance - real part [$\Omega$]', color='r')
ax[0].legend()

ax[1].plot(wake.f*1e-9, np.imag(wake.Z), c='b', lw=1.5, label='FIT+Wakis')
ax[1].plot(cstZReIm[0], cstZReIm[2], c='k', ls='--', lw=1.5, label='CST')
ax[1].set_xlabel('f [GHz]')
ax[1].set_ylabel('Longitudinal impedance - imaginary part [$\Omega$]', color='b')
ax[1].legend()

#fig.suptitle('Benchmark with CST Wakefield Solver')
fig.tight_layout()
fig.savefig('results_beta09_sigma100_wl40/cfr_real_imag.png')

plt.show()
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\O'
# <>:16: SyntaxWarning: invalid escape sequence '\O'
# <>:10: SyntaxWarning: invalid escape sequence '\O'
# <>:16: SyntaxWarning: invalid escape sequence '\O'
# /tmp/ipykernel_1379871/3828951745.py:10: SyntaxWarning: invalid escape sequence '\O'
#   ax[0].set_ylabel('Longitudinal impedance - real part [$\Omega$]', color='r')
# /tmp/ipykernel_1379871/3828951745.py:16: SyntaxWarning: invalid escape sequence '\O'
#   ax[1].set_ylabel('Longitudinal impedance - imaginary part [$\Omega$]', color='b')
